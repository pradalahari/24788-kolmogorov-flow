# %%
from google.colab import drive
drive.mount('/content/drive')

import sys, os
os.chdir('/content/drive/MyDrive/Colab Notebooks/24788_project')
sys.path.insert(0, '.')

# Train U-Net
# !python train.py --model unet --data_path ./data/KolmFlow_valid_256.h5 --epochs 50 --batch_size 32 --stride 2
# Out:
# Mounted at /content/drive
# Using device: cuda
# Train samples: 200, Val samples: 56
# Loaded normalizer: mean=-0.0000, std=3.5004
# Train pairs: 20000, Val pairs: 5600
# Model: unet | Parameters: 7,699,009
# Model compiled with torch.compile()
# Epoch   1/50 | Train Loss: 0.008378 | Val Loss: 0.002979 | Val NRMSE: 0.0535 | LR: 9.99e-04 | Time: 207.3s
#   → Saved best model (val_loss=0.002979)
# Epoch   2/50 | Train Loss: 0.001982 | Val Loss: 0.002404 | Val NRMSE: 0.0480 | LR: 9.96e-04 | Time: 62.5s
#   → Saved best model (val_loss=0.002404)
# Epoch   3/50 | Train Loss: 0.001665 | Val Loss: 0.001920 | Val NRMSE: 0.0428 | LR: 9.91e-04 | Time: 55.8s
#   → Saved best model (val_loss=0.001920)
# Epoch   4/50 | Train Loss: 0.001574 | Val Loss: 0.001417 | Val NRMSE: 0.0366 | LR: 9.84e-04 | Time: 55.5s
#   → Saved best model (val_loss=0.001417)
# Epoch   5/50 | Train Loss: 0.001512 | Val Loss: 0.001790 | Val NRMSE: 0.0412 | LR: 9.76e-04 | Time: 55.4s
# Epoch   6/50 | Train Loss: 0.001355 | Val Loss: 0.001788 | Val NRMSE: 0.0413 | LR: 9.65e-04 | Time: 55.4s
# Epoch   7/50 | Train Loss: 0.001345 | Val Loss: 0.001454 | Val NRMSE: 0.0374 | LR: 9.52e-04 | Time: 55.6s
# Epoch   8/50 | Train Loss: 0.001375 | Val Loss: 0.001116 | Val NRMSE: 0.0326 | LR: 9.38e-04 | Time: 55.5s
#   → Saved best model (val_loss=0.001116)
# Epoch   9/50 | Train Loss: 0.001266 | Val Loss: 0.001362 | Val NRMSE: 0.0361 | LR: 9.22e-04 | Time: 55.5s
# Epoch  10/50 | Train Loss: 0.001226 | Val Loss: 0.001076 | Val NRMSE: 0.0316 | LR: 9.05e-04 | Time: 55.4s
#   → Saved best model (val_loss=0.001076)
# Epoch  11/50 | Train Loss: 0.001270 | Val Loss: 0.001316 | Val NRMSE: 0.0355 | LR: 8.85e-04 | Time: 55.6s
# Epoch  12/50 | Train Loss: 0.001222 | Val Loss: 0.001695 | Val NRMSE: 0.0404 | LR: 8.64e-04 | Time: 55.4s
# Epoch  13/50 | Train Loss: 0.001286 | Val Loss: 0.001159 | Val NRMSE: 0.0332 | LR: 8.42e-04 | Time: 55.4s
# Epoch  14/50 | Train Loss: 0.001164 | Val Loss: 0.001321 | Val NRMSE: 0.0356 | LR: 8.19e-04 | Time: 55.6s
# Epoch  15/50 | Train Loss: 0.001124 | Val Loss: 0.000951 | Val NRMSE: 0.0299 | LR: 7.94e-04 | Time: 55.5s
#   → Saved best model (val_loss=0.000951)
# Epoch  16/50 | Train Loss: 0.001105 | Val Loss: 0.001370 | Val NRMSE: 0.0361 | LR: 7.68e-04 | Time: 55.5s
# Epoch  17/50 | Train Loss: 0.001119 | Val Loss: 0.001618 | Val NRMSE: 0.0396 | LR: 7.41e-04 | Time: 55.5s
# Epoch  18/50 | Train Loss: 0.001096 | Val Loss: 0.001236 | Val NRMSE: 0.0344 | LR: 7.13e-04 | Time: 55.5s
# Epoch  19/50 | Train Loss: 0.001112 | Val Loss: 0.001291 | Val NRMSE: 0.0351 | LR: 6.84e-04 | Time: 55.4s
# Epoch  20/50 | Train Loss: 0.001086 | Val Loss: 0.002205 | Val NRMSE: 0.0463 | LR: 6.55e-04 | Time: 55.3s
# Epoch  21/50 | Train Loss: 0.001047 | Val Loss: 0.001778 | Val NRMSE: 0.0414 | LR: 6.24e-04 | Time: 55.4s
# Epoch  22/50 | Train Loss: 0.001015 | Val Loss: 0.000882 | Val NRMSE: 0.0288 | LR: 5.94e-04 | Time: 55.6s
#   → Saved best model (val_loss=0.000882)
# Epoch  23/50 | Train Loss: 0.000950 | Val Loss: 0.001255 | Val NRMSE: 0.0347 | LR: 5.63e-04 | Time: 55.4s
# Epoch  24/50 | Train Loss: 0.000955 | Val Loss: 0.001090 | Val NRMSE: 0.0321 | LR: 5.31e-04 | Time: 55.5s
# Epoch  25/50 | Train Loss: 0.000896 | Val Loss: 0.000975 | Val NRMSE: 0.0304 | LR: 5.00e-04 | Time: 55.4s
# Epoch  26/50 | Train Loss: 0.000932 | Val Loss: 0.000946 | Val NRMSE: 0.0300 | LR: 4.69e-04 | Time: 55.4s
# Epoch  27/50 | Train Loss: 0.000864 | Val Loss: 0.000839 | Val NRMSE: 0.0280 | LR: 4.37e-04 | Time: 55.5s
#   → Saved best model (val_loss=0.000839)
# Epoch  28/50 | Train Loss: 0.000829 | Val Loss: 0.000812 | Val NRMSE: 0.0276 | LR: 4.06e-04 | Time: 55.5s
#   → Saved best model (val_loss=0.000812)
# Epoch  29/50 | Train Loss: 0.000867 | Val Loss: 0.001032 | Val NRMSE: 0.0315 | LR: 3.76e-04 | Time: 55.5s
# Epoch  30/50 | Train Loss: 0.000836 | Val Loss: 0.000743 | Val NRMSE: 0.0263 | LR: 3.45e-04 | Time: 55.4s
#   → Saved best model (val_loss=0.000743)
# Epoch  31/50 | Train Loss: 0.000782 | Val Loss: 0.001071 | Val NRMSE: 0.0320 | LR: 3.16e-04 | Time: 55.4s
# Epoch  32/50 | Train Loss: 0.000766 | Val Loss: 0.000884 | Val NRMSE: 0.0289 | LR: 2.87e-04 | Time: 55.5s
# Epoch  33/50 | Train Loss: 0.000770 | Val Loss: 0.000723 | Val NRMSE: 0.0259 | LR: 2.59e-04 | Time: 55.4s
#   → Saved best model (val_loss=0.000723)
# Epoch  34/50 | Train Loss: 0.000752 | Val Loss: 0.000728 | Val NRMSE: 0.0260 | LR: 2.32e-04 | Time: 55.4s
# Epoch  35/50 | Train Loss: 0.000690 | Val Loss: 0.000851 | Val NRMSE: 0.0284 | LR: 2.06e-04 | Time: 55.5s
# Epoch  36/50 | Train Loss: 0.000669 | Val Loss: 0.000649 | Val NRMSE: 0.0245 | LR: 1.81e-04 | Time: 55.4s
#   → Saved best model (val_loss=0.000649)
# Epoch  37/50 | Train Loss: 0.000621 | Val Loss: 0.000695 | Val NRMSE: 0.0254 | LR: 1.58e-04 | Time: 55.5s
# Epoch  38/50 | Train Loss: 0.000626 | Val Loss: 0.000641 | Val NRMSE: 0.0244 | LR: 1.36e-04 | Time: 55.4s
#   → Saved best model (val_loss=0.000641)
# Epoch  39/50 | Train Loss: 0.000618 | Val Loss: 0.000731 | Val NRMSE: 0.0262 | LR: 1.15e-04 | Time: 55.5s
# Epoch  40/50 | Train Loss: 0.000593 | Val Loss: 0.000620 | Val NRMSE: 0.0239 | LR: 9.55e-05 | Time: 55.4s
#   → Saved best model (val_loss=0.000620)
# Epoch  41/50 | Train Loss: 0.000550 | Val Loss: 0.000645 | Val NRMSE: 0.0244 | LR: 7.78e-05 | Time: 55.3s
# Epoch  42/50 | Train Loss: 0.000521 | Val Loss: 0.000596 | Val NRMSE: 0.0234 | LR: 6.18e-05 | Time: 55.4s
#   → Saved best model (val_loss=0.000596)
# Epoch  43/50 | Train Loss: 0.000511 | Val Loss: 0.000613 | Val NRMSE: 0.0238 | LR: 4.76e-05 | Time: 55.5s
# Epoch  44/50 | Train Loss: 0.000496 | Val Loss: 0.000597 | Val NRMSE: 0.0234 | LR: 3.51e-05 | Time: 55.5s
# Epoch  45/50 | Train Loss: 0.000474 | Val Loss: 0.000568 | Val NRMSE: 0.0228 | LR: 2.45e-05 | Time: 55.5s
#   → Saved best model (val_loss=0.000568)
# Epoch  46/50 | Train Loss: 0.000468 | Val Loss: 0.000571 | Val NRMSE: 0.0229 | LR: 1.57e-05 | Time: 55.4s
# Epoch  47/50 | Train Loss: 0.000466 | Val Loss: 0.000580 | Val NRMSE: 0.0230 | LR: 8.86e-06 | Time: 55.4s
# Epoch  48/50 | Train Loss: 0.000438 | Val Loss: 0.000568 | Val NRMSE: 0.0228 | LR: 3.94e-06 | Time: 55.4s
#   → Saved best model (val_loss=0.000568)
# Epoch  49/50 | Train Loss: 0.000452 | Val Loss: 0.000569 | Val NRMSE: 0.0228 | LR: 9.87e-07 | Time: 55.5s
# Epoch  50/50 | Train Loss: 0.000443 | Val Loss: 0.000556 | Val NRMSE: 0.0225 | LR: 0.00e+00 | Time: 55.5s
#   → Saved best model (val_loss=0.000556)
# Figure(800x500)
# Done!

# %%
# !python train.py --model fno --data_path ./data/KolmFlow_valid_256.h5 --epochs 50 --batch_size 32 --stride 2
# Out:
# Using device: cuda
# Train samples: 200, Val samples: 56
# Loaded normalizer: mean=-0.0000, std=3.5004
# Train pairs: 20000, Val pairs: 5600
# Model: fno | Parameters: 2,103,617
# Model compiled with torch.compile()
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:2156: UserWarning: Torchinductor does not support code generation for complex operators. Performance may be worse than eager.
#   warnings.warn(
# Epoch   1/50 | Train Loss: 0.017679 | Val Loss: 0.002186 | Val NRMSE: 0.0446 | LR: 9.99e-04 | Time: 67.2s
#   → Saved best model (val_loss=0.002186)
# Epoch   2/50 | Train Loss: 0.001643 | Val Loss: 0.002227 | Val NRMSE: 0.0438 | LR: 9.96e-04 | Time: 46.8s
# Epoch   3/50 | Train Loss: 0.001372 | Val Loss: 0.001581 | Val NRMSE: 0.0381 | LR: 9.91e-04 | Time: 42.0s
#   → Saved best model (val_loss=0.001581)
# Epoch   4/50 | Train Loss: 0.001275 | Val Loss: 0.001404 | Val NRMSE: 0.0353 | LR: 9.84e-04 | Time: 41.3s
#   → Saved best model (val_loss=0.001404)
# Epoch   5/50 | Train Loss: 0.001226 | Val Loss: 0.001446 | Val NRMSE: 0.0361 | LR: 9.76e-04 | Time: 41.3s
# Epoch   6/50 | Train Loss: 0.001135 | Val Loss: 0.001379 | Val NRMSE: 0.0352 | LR: 9.65e-04 | Time: 41.9s
#   → Saved best model (val_loss=0.001379)
# Epoch   7/50 | Train Loss: 0.001096 | Val Loss: 0.001502 | Val NRMSE: 0.0373 | LR: 9.52e-04 | Time: 41.7s
# Epoch   8/50 | Train Loss: 0.001032 | Val Loss: 0.001273 | Val NRMSE: 0.0336 | LR: 9.38e-04 | Time: 41.6s
#   → Saved best model (val_loss=0.001273)
# Epoch   9/50 | Train Loss: 0.001075 | Val Loss: 0.001796 | Val NRMSE: 0.0387 | LR: 9.22e-04 | Time: 41.8s
# Epoch  10/50 | Train Loss: 0.000985 | Val Loss: 0.001272 | Val NRMSE: 0.0334 | LR: 9.05e-04 | Time: 41.7s
#   → Saved best model (val_loss=0.001272)
# Epoch  11/50 | Train Loss: 0.000984 | Val Loss: 0.001254 | Val NRMSE: 0.0333 | LR: 8.85e-04 | Time: 41.7s
#   → Saved best model (val_loss=0.001254)
# Epoch  12/50 | Train Loss: 0.000954 | Val Loss: 0.001223 | Val NRMSE: 0.0330 | LR: 8.64e-04 | Time: 41.2s
#   → Saved best model (val_loss=0.001223)
# Epoch  13/50 | Train Loss: 0.000920 | Val Loss: 0.001191 | Val NRMSE: 0.0325 | LR: 8.42e-04 | Time: 41.1s
#   → Saved best model (val_loss=0.001191)
# Epoch  14/50 | Train Loss: 0.000860 | Val Loss: 0.001244 | Val NRMSE: 0.0332 | LR: 8.19e-04 | Time: 41.8s
# Epoch  15/50 | Train Loss: 0.000823 | Val Loss: 0.001221 | Val NRMSE: 0.0326 | LR: 7.94e-04 | Time: 41.7s
# Epoch  16/50 | Train Loss: 0.000860 | Val Loss: 0.001298 | Val NRMSE: 0.0343 | LR: 7.68e-04 | Time: 41.8s
# Epoch  17/50 | Train Loss: 0.000788 | Val Loss: 0.001180 | Val NRMSE: 0.0323 | LR: 7.41e-04 | Time: 41.3s
#   → Saved best model (val_loss=0.001180)
# Epoch  18/50 | Train Loss: 0.000735 | Val Loss: 0.001085 | Val NRMSE: 0.0307 | LR: 7.13e-04 | Time: 41.7s
#   → Saved best model (val_loss=0.001085)
# Epoch  19/50 | Train Loss: 0.000756 | Val Loss: 0.001176 | Val NRMSE: 0.0323 | LR: 6.84e-04 | Time: 41.7s
# Epoch  20/50 | Train Loss: 0.000719 | Val Loss: 0.001004 | Val NRMSE: 0.0295 | LR: 6.55e-04 | Time: 41.4s
#   → Saved best model (val_loss=0.001004)
# Epoch  21/50 | Train Loss: 0.000703 | Val Loss: 0.001053 | Val NRMSE: 0.0301 | LR: 6.24e-04 | Time: 41.8s
# Epoch  22/50 | Train Loss: 0.000669 | Val Loss: 0.001093 | Val NRMSE: 0.0310 | LR: 5.94e-04 | Time: 41.8s
# Epoch  23/50 | Train Loss: 0.000610 | Val Loss: 0.001109 | Val NRMSE: 0.0313 | LR: 5.63e-04 | Time: 41.1s
# Epoch  24/50 | Train Loss: 0.000611 | Val Loss: 0.000926 | Val NRMSE: 0.0282 | LR: 5.31e-04 | Time: 41.7s
#   → Saved best model (val_loss=0.000926)
# Epoch  25/50 | Train Loss: 0.000615 | Val Loss: 0.000922 | Val NRMSE: 0.0279 | LR: 5.00e-04 | Time: 41.9s
#   → Saved best model (val_loss=0.000922)
# Epoch  26/50 | Train Loss: 0.000550 | Val Loss: 0.001038 | Val NRMSE: 0.0293 | LR: 4.69e-04 | Time: 41.7s
# Epoch  27/50 | Train Loss: 0.000538 | Val Loss: 0.000911 | Val NRMSE: 0.0280 | LR: 4.37e-04 | Time: 41.3s
#   → Saved best model (val_loss=0.000911)
# Epoch  28/50 | Train Loss: 0.000497 | Val Loss: 0.000897 | Val NRMSE: 0.0273 | LR: 4.06e-04 | Time: 41.6s
#   → Saved best model (val_loss=0.000897)
# Epoch  29/50 | Train Loss: 0.000493 | Val Loss: 0.000967 | Val NRMSE: 0.0285 | LR: 3.76e-04 | Time: 41.7s
# Epoch  30/50 | Train Loss: 0.000465 | Val Loss: 0.000897 | Val NRMSE: 0.0277 | LR: 3.45e-04 | Time: 41.7s
#   → Saved best model (val_loss=0.000897)
# Epoch  31/50 | Train Loss: 0.000405 | Val Loss: 0.000853 | Val NRMSE: 0.0269 | LR: 3.16e-04 | Time: 41.8s
#   → Saved best model (val_loss=0.000853)
# Epoch  32/50 | Train Loss: 0.000415 | Val Loss: 0.000846 | Val NRMSE: 0.0260 | LR: 2.87e-04 | Time: 41.9s
#   → Saved best model (val_loss=0.000846)
# Epoch  33/50 | Train Loss: 0.000389 | Val Loss: 0.000787 | Val NRMSE: 0.0256 | LR: 2.59e-04 | Time: 41.3s
#   → Saved best model (val_loss=0.000787)
# Epoch  34/50 | Train Loss: 0.000347 | Val Loss: 0.000754 | Val NRMSE: 0.0252 | LR: 2.32e-04 | Time: 41.6s
#   → Saved best model (val_loss=0.000754)
# Epoch  35/50 | Train Loss: 0.000337 | Val Loss: 0.000758 | Val NRMSE: 0.0250 | LR: 2.06e-04 | Time: 41.8s
# Epoch  36/50 | Train Loss: 0.000315 | Val Loss: 0.000817 | Val NRMSE: 0.0253 | LR: 1.81e-04 | Time: 41.4s
# Epoch  37/50 | Train Loss: 0.000301 | Val Loss: 0.000702 | Val NRMSE: 0.0238 | LR: 1.58e-04 | Time: 40.9s
#   → Saved best model (val_loss=0.000702)
# Epoch  38/50 | Train Loss: 0.000273 | Val Loss: 0.000711 | Val NRMSE: 0.0239 | LR: 1.36e-04 | Time: 41.7s
# Epoch  39/50 | Train Loss: 0.000255 | Val Loss: 0.000699 | Val NRMSE: 0.0236 | LR: 1.15e-04 | Time: 41.7s
#   → Saved best model (val_loss=0.000699)
# Epoch  40/50 | Train Loss: 0.000241 | Val Loss: 0.000705 | Val NRMSE: 0.0237 | LR: 9.55e-05 | Time: 41.3s
# Epoch  41/50 | Train Loss: 0.000222 | Val Loss: 0.000663 | Val NRMSE: 0.0229 | LR: 7.78e-05 | Time: 41.6s
#   → Saved best model (val_loss=0.000663)
# Epoch  42/50 | Train Loss: 0.000208 | Val Loss: 0.000659 | Val NRMSE: 0.0226 | LR: 6.18e-05 | Time: 41.8s
#   → Saved best model (val_loss=0.000659)
# Epoch  43/50 | Train Loss: 0.000194 | Val Loss: 0.000650 | Val NRMSE: 0.0225 | LR: 4.76e-05 | Time: 41.3s
#   → Saved best model (val_loss=0.000650)
# Epoch  44/50 | Train Loss: 0.000184 | Val Loss: 0.000641 | Val NRMSE: 0.0222 | LR: 3.51e-05 | Time: 41.9s
#   → Saved best model (val_loss=0.000641)
# Epoch  45/50 | Train Loss: 0.000174 | Val Loss: 0.000631 | Val NRMSE: 0.0221 | LR: 2.45e-05 | Time: 41.8s
#   → Saved best model (val_loss=0.000631)
# Epoch  46/50 | Train Loss: 0.000166 | Val Loss: 0.000619 | Val NRMSE: 0.0219 | LR: 1.57e-05 | Time: 41.7s
#   → Saved best model (val_loss=0.000619)
# Epoch  47/50 | Train Loss: 0.000159 | Val Loss: 0.000618 | Val NRMSE: 0.0218 | LR: 8.86e-06 | Time: 41.7s
#   → Saved best model (val_loss=0.000618)
# Epoch  48/50 | Train Loss: 0.000154 | Val Loss: 0.000618 | Val NRMSE: 0.0218 | LR: 3.94e-06 | Time: 41.2s
#   → Saved best model (val_loss=0.000618)
# Epoch  49/50 | Train Loss: 0.000150 | Val Loss: 0.000615 | Val NRMSE: 0.0217 | LR: 9.87e-07 | Time: 41.2s
#   → Saved best model (val_loss=0.000615)
# Epoch  50/50 | Train Loss: 0.000148 | Val Loss: 0.000613 | Val NRMSE: 0.0216 | LR: 0.00e+00 | Time: 41.8s
#   → Saved best model (val_loss=0.000613)
# Figure(800x500)
# Done!

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys, os
os.chdir('/content/drive/MyDrive/Colab Notebooks/24788_project')
sys.path.insert(0, '.')

# !python evaluate.py --data_path ./data/KolmFlow_valid_256.h5 --ckpt_dir ./checkpoints --fig_dir ./figures
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using device: cuda
# Normalizer: mean=-0.0000, std=3.5004
# Loaded unet from epoch 50 (val_loss=0.000556, val_nrmse=0.022529793142208033)
# Loaded fno from epoch 50 (val_loss=0.000613, val_nrmse=0.021634963612471306)
#
# === One-Step NRMSE ===
# U-Net: 0.022523
# FNO:   0.021626
#
# === Autoregressive Rollout ===
#   Sample 0: U-Net final=554530.5625, FNO final=0.9235
#   Sample 1: U-Net final=445.9427, FNO final=0.9445
#   Sample 2: U-Net final=7555870.0000, FNO final=1.1225
#   Sample 3: U-Net final=17593.4766, FNO final=0.8983
#   Sample 4: U-Net final=314325.8750, FNO final=0.9004
# Figure(800x500)
#
# === Vorticity Visualizations ===
# /content/drive/MyDrive/Colab Notebooks/24788_project/utils.py:185: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Figure(1500x400)
# Figure(1500x400)
# Figure(1500x400)
# Figure(1500x400)
# Figure(1500x400)
# Figure(1500x400)
# Figure(1500x400)
# Figure(1500x400)
#
# === Log-TKE Spectrum ===
# Figure(800x500)
#
# ==================================================
# SUMMARY
# ==================================================
# Metric                         U-Net        FNO
# --------------------------------------------------
# One-step NRMSE                 0.022523     0.021626
# Rollout NRMSE (t=50)           2.2382       0.5845
# Rollout NRMSE (t=100)          1688553.1714 0.9578
# ==================================================
#
# Done! Figures saved to: ./figures
